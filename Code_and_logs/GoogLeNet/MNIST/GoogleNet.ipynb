# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import datetime
from tqdm import tqdm # for progress bar
from tensorflow.keras import datasets, layers, models, losses, Model
from tensorflow.keras.utils import to_categorical, plot_model
from tensorflow.keras.preprocessing import image
from tensorflow.keras.callbacks import TensorBoard
import logging
# Out:
# 2023-05-10 23:48:17.764002: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-05-10 23:48:17.789339: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-10 23:48:18.139141: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
def image_reshape(xtrain, xtest):
    x_train = tf.pad(xtrain, [[0, 0], [2,2], [2,2]])/255
    x_test = tf.pad(xtest, [[0, 0], [2,2], [2,2]])/255

    x_train = tf.expand_dims(x_train, axis=3, name=None)
    x_test = tf.expand_dims(x_test, axis=3, name=None)
    
    x_train = tf.repeat(x_train, 3, axis=3)
    x_test = tf.repeat(x_test, 3, axis=3)
    
    
    return x_train, x_test

# %%
with tf.device('/device:GPU:0'):
    # Reshape image 
    (x_train,y_train),(x_test,y_test) = datasets.mnist.load_data()
    x_train, x_test = image_reshape(x_train, x_test)

    # Divide training dataset into training and validation sets
    x_val = x_train[-2000:,:,:]
    y_val = y_train[-2000:]
    x_train = x_train[:-2000,:,:]
    y_train = y_train[:-2000]
    print(x_train.shape)
    print(y_train.shape)
    print(x_test.shape)
    print(y_test.shape)
    print(x_val.shape)
    print(y_val.shape)
# Out:
# 2023-05-10 23:48:18.744468: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-10 23:48:18.744560: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-10 23:48:18.758374: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-10 23:48:18.758485: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-10 23:48:18.758547: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-10 23:48:18.758601: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-10 23:48:18.919082: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-10 23:48:18.919183: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-10 23:48:18.919245: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-10 23:48:18.919296: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-10 23:48:18.919345: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-10 23:48:18.919395: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-10 23:48:19.988169: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-10 23:48:19.988290: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-10 23:48:19.988359: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-10 23:48:19.988416: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-10 23:48:19.988472: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-10 23:48:19.988532: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21190 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:01:00.0, compute capability: 8.6
# 2023-05-10 23:48:19.988733: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-10 23:48:19.988793: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 118 MB memory:  -> device: 1, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:07:00.0, compute capability: 8.6
# (58000, 32, 32, 3)
# (58000,)
# (10000, 32, 32, 3)
# (10000,)
# (2000, 32, 32, 3)
# (2000,)

# %%
def inception(x,filters_1x1,filters_3x3_reduce,filters_3x3,filters_5x5_reduce,filters_5x5,filters_pool):
    
    path1 = layers.Conv2D(filters_1x1, (1, 1), padding='same',    activation='relu')(x)
    path2 = layers.Conv2D(filters_3x3_reduce, (1, 1), padding='same', activation='relu')(x)
    path2 = layers.Conv2D(filters_3x3, (1, 1), padding='same', activation='relu')(path2)
    path3 = layers.Conv2D(filters_5x5_reduce, (1, 1), padding='same', activation='relu')(x)
    path3 = layers.Conv2D(filters_5x5, (1, 1), padding='same', activation='relu')(path3)
    path4 = layers.MaxPool2D((3, 3), strides=(1, 1), padding='same')(x)
    path4 = layers.Conv2D(filters_pool, (1, 1), padding='same', activation='relu')(path4)
    
    return tf.concat([path1, path2, path3, path4], axis=3)

# %%
inp = layers.Input(shape=(32, 32, 3))
input_tensor = layers.experimental.preprocessing.Resizing(224, 224, interpolation="bilinear", input_shape=x_train.shape[1:])(inp)
x = layers.Conv2D(64, 7, strides=2, padding='same', activation='relu')(input_tensor)
x = layers.MaxPooling2D(3, strides=2)(x)
x = layers.Conv2D(64, 1, strides=1, padding='same', activation='relu')(x)
x = layers.Conv2D(192, 3, strides=1, padding='same', activation='relu')(x)
x = layers.MaxPooling2D(3, strides=2)(x)
x = inception(x, filters_1x1=64, filters_3x3_reduce=96, filters_3x3=128, filters_5x5_reduce=16, filters_5x5=32, filters_pool=32)
x = inception(x, filters_1x1=128, filters_3x3_reduce=128, filters_3x3=192, filters_5x5_reduce=32, filters_5x5=96, filters_pool=64)
x = layers.MaxPooling2D(3, strides=2)(x)
x = inception(x, filters_1x1=192, filters_3x3_reduce=96, filters_3x3=208, filters_5x5_reduce=16, filters_5x5=48, filters_pool=64)
aux1 = layers.AveragePooling2D((5, 5), strides=3)(x)
aux1 =layers.Conv2D(128, 1, padding='same', activation='relu')(aux1)
aux1 = layers.Flatten()(aux1)
aux1 = layers.Dense(1024, activation='relu')(aux1)
aux1 = layers.Dropout(0.7)(aux1)
aux1 = layers.Dense(10, activation='softmax')(aux1)
x = inception(x, filters_1x1=160, filters_3x3_reduce=112, filters_3x3=224, filters_5x5_reduce=24, filters_5x5=64, filters_pool=64)
x = inception(x, filters_1x1=128, filters_3x3_reduce=128, filters_3x3=256, filters_5x5_reduce=24, filters_5x5=64, filters_pool=64)
x = inception(x, filters_1x1=112, filters_3x3_reduce=144, filters_3x3=288, filters_5x5_reduce=32, filters_5x5=64, filters_pool=64)
aux2 = layers.AveragePooling2D((5, 5), strides=3)(x)
aux2 =layers.Conv2D(128, 1, padding='same', activation='relu')(aux2)
aux2 = layers.Flatten()(aux2)
aux2 = layers.Dense(1024, activation='relu')(aux2)
aux2 = layers.Dropout(0.7)(aux2) 
aux2 = layers.Dense(10, activation='softmax')(aux2)
x = inception(x, filters_1x1=256, filters_3x3_reduce=160, filters_3x3=320, filters_5x5_reduce=32, filters_5x5=128, filters_pool=128)
x = layers.MaxPooling2D(3, strides=2)(x)
x = inception(x, filters_1x1=256, filters_3x3_reduce=160, filters_3x3=320, filters_5x5_reduce=32, filters_5x5=128, filters_pool=128)
x = inception(x, filters_1x1=384, filters_3x3_reduce=192, filters_3x3=384, filters_5x5_reduce=48, filters_5x5=128, filters_pool=128)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.4)(x)
out = layers.Dense(10, activation='softmax')(x)

# %%
model = Model(inputs = inp, outputs = [out, aux1, aux2])

# %%
with tf.device('/device:GPU:0'):
      model.compile(optimizer='adam', 
                  loss=[losses.sparse_categorical_crossentropy,
                        losses.sparse_categorical_crossentropy,
                        losses.sparse_categorical_crossentropy],
                  loss_weights=[1, 0.3, 0.3],
                  metrics=['accuracy'])

      log_dir = "logs/google/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
      tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

      # Define the CSVLogger callback
      csv_logger = tf.keras.callbacks.CSVLogger('googletraining.log')

      callbacks = [tensorboard_callback, csv_logger]

      history = model.fit(x_train, [y_train, y_train, y_train], validation_data=(x_val, [y_val, y_val, y_val]), batch_size=64, epochs=40, callbacks=callbacks)
# Out:
# Epoch 1/40
# 2023-05-10 23:48:24.884662: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2023-05-10 23:48:25.836487: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:637] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-05-10 23:48:26.042830: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x5559449b9f10 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-05-10 23:48:26.042857: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): NVIDIA GeForce RTX 3090, Compute Capability 8.6
# 2023-05-10 23:48:26.042862: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (1): NVIDIA GeForce RTX 3090, Compute Capability 8.6
# 2023-05-10 23:48:26.046879: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-05-10 23:48:26.120863: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 907/907 [==============================] - 60s 49ms/step - loss: 1.1169 - dense_4_loss: 0.8330 - dense_1_loss: 0.4440 - dense_3_loss: 0.5026 - dense_4_accuracy: 0.7124 - dense_1_accuracy: 0.8524 - dense_3_accuracy: 0.8311 - val_loss: 0.1851 - val_dense_4_loss: 0.1398 - val_dense_1_loss: 0.0726 - val_dense_3_loss: 0.0781 - val_dense_4_accuracy: 0.9555 - val_dense_1_accuracy: 0.9800 - val_dense_3_accuracy: 0.9790
# Epoch 2/40
# 907/907 [==============================] - 43s 47ms/step - loss: 0.2094 - dense_4_loss: 0.1445 - dense_1_loss: 0.1034 - dense_3_loss: 0.1132 - dense_4_accuracy: 0.9567 - dense_1_accuracy: 0.9689 - dense_3_accuracy: 0.9658 - val_loss: 0.1037 - val_dense_4_loss: 0.0771 - val_dense_1_loss: 0.0426 - val_dense_3_loss: 0.0460 - val_dense_4_accuracy: 0.9750 - val_dense_1_accuracy: 0.9885 - val_dense_3_accuracy: 0.9890
# Epoch 3/40
# 907/907 [==============================] - 43s 47ms/step - loss: 0.1357 - dense_4_loss: 0.0894 - dense_1_loss: 0.0752 - dense_3_loss: 0.0791 - dense_4_accuracy: 0.9729 - dense_1_accuracy: 0.9778 - dense_3_accuracy: 0.9759 - val_loss: 0.0841 - val_dense_4_loss: 0.0614 - val_dense_1_loss: 0.0362 - val_dense_3_loss: 0.0396 - val_dense_4_accuracy: 0.9830 - val_dense_1_accuracy: 0.9880 - val_dense_3_accuracy: 0.9900
# Epoch 4/40
# 907/907 [==============================] - 43s 47ms/step - loss: 0.1077 - dense_4_loss: 0.0708 - dense_1_loss: 0.0601 - dense_3_loss: 0.0629 - dense_4_accuracy: 0.9785 - dense_1_accuracy: 0.9819 - dense_3_accuracy: 0.9808 - val_loss: 0.1461 - val_dense_4_loss: 0.1212 - val_dense_1_loss: 0.0339 - val_dense_3_loss: 0.0490 - val_dense_4_accuracy: 0.9630 - val_dense_1_accuracy: 0.9920 - val_dense_3_accuracy: 0.9870
# Epoch 5/40
# 907/907 [==============================] - 42s 47ms/step - loss: 0.0934 - dense_4_loss: 0.0600 - dense_1_loss: 0.0539 - dense_3_loss: 0.0573 - dense_4_accuracy: 0.9816 - dense_1_accuracy: 0.9835 - dense_3_accuracy: 0.9828 - val_loss: 0.0562 - val_dense_4_loss: 0.0343 - val_dense_1_loss: 0.0350 - val_dense_3_loss: 0.0379 - val_dense_4_accuracy: 0.9905 - val_dense_1_accuracy: 0.9925 - val_dense_3_accuracy: 0.9905
# Epoch 6/40
# 907/907 [==============================] - 42s 46ms/step - loss: 0.0844 - dense_4_loss: 0.0554 - dense_1_loss: 0.0463 - dense_3_loss: 0.0501 - dense_4_accuracy: 0.9830 - dense_1_accuracy: 0.9858 - dense_3_accuracy: 0.9847 - val_loss: 0.0598 - val_dense_4_loss: 0.0376 - val_dense_1_loss: 0.0309 - val_dense_3_loss: 0.0431 - val_dense_4_accuracy: 0.9895 - val_dense_1_accuracy: 0.9930 - val_dense_3_accuracy: 0.9870
# Epoch 7/40
# 907/907 [==============================] - 42s 46ms/step - loss: 0.0761 - dense_4_loss: 0.0487 - dense_1_loss: 0.0443 - dense_3_loss: 0.0471 - dense_4_accuracy: 0.9849 - dense_1_accuracy: 0.9864 - dense_3_accuracy: 0.9858 - val_loss: 0.0644 - val_dense_4_loss: 0.0369 - val_dense_1_loss: 0.0491 - val_dense_3_loss: 0.0425 - val_dense_4_accuracy: 0.9900 - val_dense_1_accuracy: 0.9875 - val_dense_3_accuracy: 0.9875
# Epoch 8/40
# 907/907 [==============================] - 42s 46ms/step - loss: 0.0678 - dense_4_loss: 0.0438 - dense_1_loss: 0.0384 - dense_3_loss: 0.0415 - dense_4_accuracy: 0.9863 - dense_1_accuracy: 0.9881 - dense_3_accuracy: 0.9870 - val_loss: 0.0512 - val_dense_4_loss: 0.0326 - val_dense_1_loss: 0.0346 - val_dense_3_loss: 0.0274 - val_dense_4_accuracy: 0.9905 - val_dense_1_accuracy: 0.9915 - val_dense_3_accuracy: 0.9940
# Epoch 9/40
# 907/907 [==============================] - 43s 47ms/step - loss: 0.0613 - dense_4_loss: 0.0395 - dense_1_loss: 0.0346 - dense_3_loss: 0.0382 - dense_4_accuracy: 0.9878 - dense_1_accuracy: 0.9893 - dense_3_accuracy: 0.9881 - val_loss: 0.0528 - val_dense_4_loss: 0.0315 - val_dense_1_loss: 0.0408 - val_dense_3_loss: 0.0303 - val_dense_4_accuracy: 0.9940 - val_dense_1_accuracy: 0.9905 - val_dense_3_accuracy: 0.9950
# Epoch 10/40
# 907/907 [==============================] - 43s 47ms/step - loss: 0.0570 - dense_4_loss: 0.0358 - dense_1_loss: 0.0338 - dense_3_loss: 0.0368 - dense_4_accuracy: 0.9891 - dense_1_accuracy: 0.9898 - dense_3_accuracy: 0.9886 - val_loss: 0.0465 - val_dense_4_loss: 0.0281 - val_dense_1_loss: 0.0365 - val_dense_3_loss: 0.0247 - val_dense_4_accuracy: 0.9935 - val_dense_1_accuracy: 0.9910 - val_dense_3_accuracy: 0.9950
# Epoch 11/40
# 907/907 [==============================] - 43s 47ms/step - loss: 0.0499 - dense_4_loss: 0.0309 - dense_1_loss: 0.0313 - dense_3_loss: 0.0322 - dense_4_accuracy: 0.9901 - dense_1_accuracy: 0.9904 - dense_3_accuracy: 0.9904 - val_loss: 0.0421 - val_dense_4_loss: 0.0247 - val_dense_1_loss: 0.0366 - val_dense_3_loss: 0.0212 - val_dense_4_accuracy: 0.9935 - val_dense_1_accuracy: 0.9935 - val_dense_3_accuracy: 0.9965
# Epoch 12/40
# 907/907 [==============================] - 43s 47ms/step - loss: 0.0494 - dense_4_loss: 0.0313 - dense_1_loss: 0.0294 - dense_3_loss: 0.0308 - dense_4_accuracy: 0.9899 - dense_1_accuracy: 0.9912 - dense_3_accuracy: 0.9905 - val_loss: 0.0507 - val_dense_4_loss: 0.0322 - val_dense_1_loss: 0.0309 - val_dense_3_loss: 0.0310 - val_dense_4_accuracy: 0.9935 - val_dense_1_accuracy: 0.9915 - val_dense_3_accuracy: 0.9925
# Epoch 13/40
# 907/907 [==============================] - 43s 47ms/step - loss: 0.0466 - dense_4_loss: 0.0295 - dense_1_loss: 0.0286 - dense_3_loss: 0.0282 - dense_4_accuracy: 0.9909 - dense_1_accuracy: 0.9913 - dense_3_accuracy: 0.9914 - val_loss: 0.0369 - val_dense_4_loss: 0.0226 - val_dense_1_loss: 0.0257 - val_dense_3_loss: 0.0218 - val_dense_4_accuracy: 0.9955 - val_dense_1_accuracy: 0.9955 - val_dense_3_accuracy: 0.9960
# Epoch 14/40
# 907/907 [==============================] - 42s 47ms/step - loss: 0.0421 - dense_4_loss: 0.0263 - dense_1_loss: 0.0259 - dense_3_loss: 0.0267 - dense_4_accuracy: 0.9917 - dense_1_accuracy: 0.9919 - dense_3_accuracy: 0.9918 - val_loss: 0.0389 - val_dense_4_loss: 0.0238 - val_dense_1_loss: 0.0264 - val_dense_3_loss: 0.0240 - val_dense_4_accuracy: 0.9955 - val_dense_1_accuracy: 0.9940 - val_dense_3_accuracy: 0.9960
# Epoch 15/40
# 907/907 [==============================] - 42s 46ms/step - loss: 0.0430 - dense_4_loss: 0.0269 - dense_1_loss: 0.0251 - dense_3_loss: 0.0285 - dense_4_accuracy: 0.9919 - dense_1_accuracy: 0.9923 - dense_3_accuracy: 0.9915 - val_loss: 0.0750 - val_dense_4_loss: 0.0533 - val_dense_1_loss: 0.0425 - val_dense_3_loss: 0.0297 - val_dense_4_accuracy: 0.9875 - val_dense_1_accuracy: 0.9935 - val_dense_3_accuracy: 0.9945
# Epoch 16/40
# 907/907 [==============================] - 42s 47ms/step - loss: 0.0368 - dense_4_loss: 0.0229 - dense_1_loss: 0.0228 - dense_3_loss: 0.0235 - dense_4_accuracy: 0.9927 - dense_1_accuracy: 0.9930 - dense_3_accuracy: 0.9924 - val_loss: 0.0591 - val_dense_4_loss: 0.0459 - val_dense_1_loss: 0.0258 - val_dense_3_loss: 0.0182 - val_dense_4_accuracy: 0.9910 - val_dense_1_accuracy: 0.9955 - val_dense_3_accuracy: 0.9965
# Epoch 17/40
# 907/907 [==============================] - 42s 46ms/step - loss: 0.0357 - dense_4_loss: 0.0215 - dense_1_loss: 0.0236 - dense_3_loss: 0.0239 - dense_4_accuracy: 0.9934 - dense_1_accuracy: 0.9928 - dense_3_accuracy: 0.9927 - val_loss: 0.0482 - val_dense_4_loss: 0.0319 - val_dense_1_loss: 0.0315 - val_dense_3_loss: 0.0231 - val_dense_4_accuracy: 0.9940 - val_dense_1_accuracy: 0.9950 - val_dense_3_accuracy: 0.9965
# Epoch 18/40
# 907/907 [==============================] - 41s 46ms/step - loss: 0.0395 - dense_4_loss: 0.0255 - dense_1_loss: 0.0227 - dense_3_loss: 0.0239 - dense_4_accuracy: 0.9915 - dense_1_accuracy: 0.9928 - dense_3_accuracy: 0.9923 - val_loss: 0.0485 - val_dense_4_loss: 0.0324 - val_dense_1_loss: 0.0320 - val_dense_3_loss: 0.0218 - val_dense_4_accuracy: 0.9935 - val_dense_1_accuracy: 0.9950 - val_dense_3_accuracy: 0.9975
# Epoch 19/40
# 907/907 [==============================] - 41s 46ms/step - loss: 0.0317 - dense_4_loss: 0.0197 - dense_1_loss: 0.0200 - dense_3_loss: 0.0200 - dense_4_accuracy: 0.9934 - dense_1_accuracy: 0.9938 - dense_3_accuracy: 0.9936 - val_loss: 0.0565 - val_dense_4_loss: 0.0417 - val_dense_1_loss: 0.0262 - val_dense_3_loss: 0.0232 - val_dense_4_accuracy: 0.9920 - val_dense_1_accuracy: 0.9965 - val_dense_3_accuracy: 0.9955
# Epoch 20/40
# 907/907 [==============================] - 41s 45ms/step - loss: 0.0320 - dense_4_loss: 0.0201 - dense_1_loss: 0.0193 - dense_3_loss: 0.0205 - dense_4_accuracy: 0.9931 - dense_1_accuracy: 0.9940 - dense_3_accuracy: 0.9939 - val_loss: 0.0601 - val_dense_4_loss: 0.0385 - val_dense_1_loss: 0.0420 - val_dense_3_loss: 0.0301 - val_dense_4_accuracy: 0.9930 - val_dense_1_accuracy: 0.9935 - val_dense_3_accuracy: 0.9955
# Epoch 21/40
# 907/907 [==============================] - 41s 45ms/step - loss: 0.0288 - dense_4_loss: 0.0179 - dense_1_loss: 0.0174 - dense_3_loss: 0.0189 - dense_4_accuracy: 0.9942 - dense_1_accuracy: 0.9949 - dense_3_accuracy: 0.9943 - val_loss: 0.0449 - val_dense_4_loss: 0.0286 - val_dense_1_loss: 0.0337 - val_dense_3_loss: 0.0207 - val_dense_4_accuracy: 0.9925 - val_dense_1_accuracy: 0.9960 - val_dense_3_accuracy: 0.9950
# Epoch 22/40
# 907/907 [==============================] - 41s 45ms/step - loss: 0.0281 - dense_4_loss: 0.0169 - dense_1_loss: 0.0185 - dense_3_loss: 0.0186 - dense_4_accuracy: 0.9949 - dense_1_accuracy: 0.9945 - dense_3_accuracy: 0.9943 - val_loss: 0.0500 - val_dense_4_loss: 0.0307 - val_dense_1_loss: 0.0360 - val_dense_3_loss: 0.0285 - val_dense_4_accuracy: 0.9945 - val_dense_1_accuracy: 0.9950 - val_dense_3_accuracy: 0.9960
# Epoch 23/40
# 907/907 [==============================] - 41s 45ms/step - loss: 0.0299 - dense_4_loss: 0.0181 - dense_1_loss: 0.0192 - dense_3_loss: 0.0203 - dense_4_accuracy: 0.9940 - dense_1_accuracy: 0.9938 - dense_3_accuracy: 0.9940 - val_loss: 0.0665 - val_dense_4_loss: 0.0469 - val_dense_1_loss: 0.0325 - val_dense_3_loss: 0.0329 - val_dense_4_accuracy: 0.9900 - val_dense_1_accuracy: 0.9960 - val_dense_3_accuracy: 0.9945
# Epoch 24/40
# 907/907 [==============================] - 41s 45ms/step - loss: 0.0250 - dense_4_loss: 0.0153 - dense_1_loss: 0.0152 - dense_3_loss: 0.0172 - dense_4_accuracy: 0.9951 - dense_1_accuracy: 0.9953 - dense_3_accuracy: 0.9950 - val_loss: 0.0405 - val_dense_4_loss: 0.0224 - val_dense_1_loss: 0.0317 - val_dense_3_loss: 0.0285 - val_dense_4_accuracy: 0.9955 - val_dense_1_accuracy: 0.9955 - val_dense_3_accuracy: 0.9960
# Epoch 25/40
# 907/907 [==============================] - 41s 45ms/step - loss: 0.0272 - dense_4_loss: 0.0163 - dense_1_loss: 0.0168 - dense_3_loss: 0.0193 - dense_4_accuracy: 0.9946 - dense_1_accuracy: 0.9950 - dense_3_accuracy: 0.9943 - val_loss: 0.0449 - val_dense_4_loss: 0.0254 - val_dense_1_loss: 0.0340 - val_dense_3_loss: 0.0311 - val_dense_4_accuracy: 0.9945 - val_dense_1_accuracy: 0.9960 - val_dense_3_accuracy: 0.9960
# Epoch 26/40
# 907/907 [==============================] - 41s 45ms/step - loss: 0.0248 - dense_4_loss: 0.0150 - dense_1_loss: 0.0167 - dense_3_loss: 0.0161 - dense_4_accuracy: 0.9954 - dense_1_accuracy: 0.9945 - dense_3_accuracy: 0.9950 - val_loss: 0.0380 - val_dense_4_loss: 0.0222 - val_dense_1_loss: 0.0292 - val_dense_3_loss: 0.0235 - val_dense_4_accuracy: 0.9955 - val_dense_1_accuracy: 0.9960 - val_dense_3_accuracy: 0.9960
# Epoch 27/40
# 907/907 [==============================] - 40s 44ms/step - loss: 0.0225 - dense_4_loss: 0.0132 - dense_1_loss: 0.0148 - dense_3_loss: 0.0161 - dense_4_accuracy: 0.9957 - dense_1_accuracy: 0.9950 - dense_3_accuracy: 0.9952 - val_loss: 0.0860 - val_dense_4_loss: 0.0498 - val_dense_1_loss: 0.0559 - val_dense_3_loss: 0.0646 - val_dense_4_accuracy: 0.9910 - val_dense_1_accuracy: 0.9930 - val_dense_3_accuracy: 0.9900
# Epoch 28/40
# 907/907 [==============================] - 41s 45ms/step - loss: 0.0244 - dense_4_loss: 0.0149 - dense_1_loss: 0.0164 - dense_3_loss: 0.0152 - dense_4_accuracy: 0.9950 - dense_1_accuracy: 0.9950 - dense_3_accuracy: 0.9954 - val_loss: 0.0412 - val_dense_4_loss: 0.0258 - val_dense_1_loss: 0.0243 - val_dense_3_loss: 0.0271 - val_dense_4_accuracy: 0.9940 - val_dense_1_accuracy: 0.9965 - val_dense_3_accuracy: 0.9955
# Epoch 29/40
# 907/907 [==============================] - 41s 45ms/step - loss: 0.0236 - dense_4_loss: 0.0142 - dense_1_loss: 0.0168 - dense_3_loss: 0.0145 - dense_4_accuracy: 0.9955 - dense_1_accuracy: 0.9956 - dense_3_accuracy: 0.9956 - val_loss: 0.0421 - val_dense_4_loss: 0.0243 - val_dense_1_loss: 0.0267 - val_dense_3_loss: 0.0327 - val_dense_4_accuracy: 0.9955 - val_dense_1_accuracy: 0.9960 - val_dense_3_accuracy: 0.9945
# Epoch 30/40
# 907/907 [==============================] - 41s 45ms/step - loss: 0.0200 - dense_4_loss: 0.0116 - dense_1_loss: 0.0133 - dense_3_loss: 0.0150 - dense_4_accuracy: 0.9961 - dense_1_accuracy: 0.9959 - dense_3_accuracy: 0.9956 - val_loss: 0.0451 - val_dense_4_loss: 0.0261 - val_dense_1_loss: 0.0313 - val_dense_3_loss: 0.0321 - val_dense_4_accuracy: 0.9960 - val_dense_1_accuracy: 0.9960 - val_dense_3_accuracy: 0.9970
# Epoch 31/40
# 907/907 [==============================] - 41s 45ms/step - loss: 0.0216 - dense_4_loss: 0.0130 - dense_1_loss: 0.0136 - dense_3_loss: 0.0151 - dense_4_accuracy: 0.9959 - dense_1_accuracy: 0.9959 - dense_3_accuracy: 0.9956 - val_loss: 0.0685 - val_dense_4_loss: 0.0416 - val_dense_1_loss: 0.0546 - val_dense_3_loss: 0.0348 - val_dense_4_accuracy: 0.9930 - val_dense_1_accuracy: 0.9925 - val_dense_3_accuracy: 0.9935
# Epoch 32/40
# 907/907 [==============================] - 41s 45ms/step - loss: 0.0232 - dense_4_loss: 0.0142 - dense_1_loss: 0.0145 - dense_3_loss: 0.0154 - dense_4_accuracy: 0.9956 - dense_1_accuracy: 0.9956 - dense_3_accuracy: 0.9955 - val_loss: 0.0502 - val_dense_4_loss: 0.0248 - val_dense_1_loss: 0.0450 - val_dense_3_loss: 0.0397 - val_dense_4_accuracy: 0.9955 - val_dense_1_accuracy: 0.9955 - val_dense_3_accuracy: 0.9960
# Epoch 33/40
# 907/907 [==============================] - 41s 45ms/step - loss: 0.0197 - dense_4_loss: 0.0113 - dense_1_loss: 0.0143 - dense_3_loss: 0.0138 - dense_4_accuracy: 0.9965 - dense_1_accuracy: 0.9957 - dense_3_accuracy: 0.9958 - val_loss: 0.0464 - val_dense_4_loss: 0.0263 - val_dense_1_loss: 0.0331 - val_dense_3_loss: 0.0340 - val_dense_4_accuracy: 0.9960 - val_dense_1_accuracy: 0.9960 - val_dense_3_accuracy: 0.9965
# Epoch 34/40
# 907/907 [==============================] - 41s 45ms/step - loss: 0.0245 - dense_4_loss: 0.0145 - dense_1_loss: 0.0160 - dense_3_loss: 0.0173 - dense_4_accuracy: 0.9956 - dense_1_accuracy: 0.9952 - dense_3_accuracy: 0.9950 - val_loss: 0.0701 - val_dense_4_loss: 0.0430 - val_dense_1_loss: 0.0519 - val_dense_3_loss: 0.0384 - val_dense_4_accuracy: 0.9905 - val_dense_1_accuracy: 0.9940 - val_dense_3_accuracy: 0.9965
# Epoch 35/40
# 907/907 [==============================] - 41s 45ms/step - loss: 0.0200 - dense_4_loss: 0.0115 - dense_1_loss: 0.0151 - dense_3_loss: 0.0133 - dense_4_accuracy: 0.9963 - dense_1_accuracy: 0.9957 - dense_3_accuracy: 0.9961 - val_loss: 0.0484 - val_dense_4_loss: 0.0262 - val_dense_1_loss: 0.0353 - val_dense_3_loss: 0.0388 - val_dense_4_accuracy: 0.9955 - val_dense_1_accuracy: 0.9955 - val_dense_3_accuracy: 0.9930
# Epoch 36/40
# 907/907 [==============================] - 41s 45ms/step - loss: 0.0222 - dense_4_loss: 0.0129 - dense_1_loss: 0.0150 - dense_3_loss: 0.0159 - dense_4_accuracy: 0.9959 - dense_1_accuracy: 0.9957 - dense_3_accuracy: 0.9954 - val_loss: 0.0653 - val_dense_4_loss: 0.0397 - val_dense_1_loss: 0.0418 - val_dense_3_loss: 0.0436 - val_dense_4_accuracy: 0.9925 - val_dense_1_accuracy: 0.9945 - val_dense_3_accuracy: 0.9945
# Epoch 37/40
# 907/907 [==============================] - 40s 45ms/step - loss: 0.0209 - dense_4_loss: 0.0126 - dense_1_loss: 0.0133 - dense_3_loss: 0.0142 - dense_4_accuracy: 0.9958 - dense_1_accuracy: 0.9958 - dense_3_accuracy: 0.9959 - val_loss: 0.0548 - val_dense_4_loss: 0.0318 - val_dense_1_loss: 0.0419 - val_dense_3_loss: 0.0345 - val_dense_4_accuracy: 0.9950 - val_dense_1_accuracy: 0.9935 - val_dense_3_accuracy: 0.9970
# Epoch 38/40
# 907/907 [==============================] - 41s 45ms/step - loss: 0.0175 - dense_4_loss: 0.0103 - dense_1_loss: 0.0119 - dense_3_loss: 0.0119 - dense_4_accuracy: 0.9965 - dense_1_accuracy: 0.9965 - dense_3_accuracy: 0.9966 - val_loss: 0.0472 - val_dense_4_loss: 0.0248 - val_dense_1_loss: 0.0461 - val_dense_3_loss: 0.0286 - val_dense_4_accuracy: 0.9965 - val_dense_1_accuracy: 0.9950 - val_dense_3_accuracy: 0.9965
# Epoch 39/40
# 907/907 [==============================] - 40s 45ms/step - loss: 0.0217 - dense_4_loss: 0.0128 - dense_1_loss: 0.0138 - dense_3_loss: 0.0158 - dense_4_accuracy: 0.9956 - dense_1_accuracy: 0.9959 - dense_3_accuracy: 0.9956 - val_loss: 0.0764 - val_dense_4_loss: 0.0484 - val_dense_1_loss: 0.0430 - val_dense_3_loss: 0.0502 - val_dense_4_accuracy: 0.9920 - val_dense_1_accuracy: 0.9950 - val_dense_3_accuracy: 0.9940
# Epoch 40/40
# 907/907 [==============================] - 40s 45ms/step - loss: 0.0204 - dense_4_loss: 0.0120 - dense_1_loss: 0.0129 - dense_3_loss: 0.0153 - dense_4_accuracy: 0.9960 - dense_1_accuracy: 0.9960 - dense_3_accuracy: 0.9952 - val_loss: 0.0521 - val_dense_4_loss: 0.0313 - val_dense_1_loss: 0.0365 - val_dense_3_loss: 0.0330 - val_dense_4_accuracy: 0.9930 - val_dense_1_accuracy: 0.9950 - val_dense_3_accuracy: 0.9940

# %%
# Plot of accuracy and loss
fig, axs = plt.subplots(2, 1, figsize=(15,15))
axs[0].plot(history.history['loss'])
axs[0].plot(history.history['val_loss'])
axs[0].title.set_text('Training Loss vs Validation Loss')
axs[0].set_xlabel('Epochs')
axs[0].set_ylabel('Loss')
axs[0].legend(['Train','Val'])
axs[1].plot(history.history['dense_4_accuracy'])
axs[1].plot(history.history['val_dense_4_accuracy'])
axs[1].title.set_text('Training Accuracy vs Validation Accuracy')
axs[1].set_xlabel('Epochs')
axs[1].set_ylabel('Accuracy')
axs[1].legend(['Train', 'Val'])

# %%
model.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 4s 12ms/step - loss: 0.0513 - dense_4_loss: 0.0330 - dense_1_loss: 0.0290 - dense_3_loss: 0.0321 - dense_4_accuracy: 0.9916 - dense_1_accuracy: 0.9928 - dense_3_accuracy: 0.9918
# [0.051311004906892776,
#  0.032968953251838684,
#  0.029020138084888458,
#  0.032119978219270706,
#  0.991599977016449,
#  0.9927999973297119,
#  0.9918000102043152]

# %%
# %reload_ext tensorboard
# %tensorboard --logdir ./logs/google
# Out:
# ERROR: Failed to launch TensorBoard (exited with 1).
# Contents of stderr:
# 2023-05-11 00:16:24.960112: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/metaverse/miniconda3/envs/mutiah/lib/python3.9/site-packages/tensorboard_data_server/bin/server: /lib/x86_64-linux-gnu/libc.so.6: version `GLIBC_2.33' not found (required by /home/metaverse/miniconda3/envs/mutiah/lib/python3.9/site-packages/tensorboard_data_server/bin/server)
# /home/metaverse/miniconda3/envs/mutiah/lib/python3.9/site-packages/tensorboard_data_server/bin/server: /lib/x86_64-linux-gnu/libc.so.6: version `GLIBC_2.34' not found (required by /home/metaverse/miniconda3/envs/mutiah/lib/python3.9/site-packages/tensorboard_data_server/bin/server)
# /home/metaverse/miniconda3/envs/mutiah/lib/python3.9/site-packages/tensorboard_data_server/bin/server: /lib/x86_64-linux-gnu/libc.so.6: version `GLIBC_2.32' not found (required by /home/metaverse/miniconda3/envs/mutiah/lib/python3.9/site-packages/tensorboard_data_server/bin/server)
# E0511 00:16:25.357892 140719387473728 application.py:125] Failed to load plugin WhatIfToolPluginLoader.load; ignoring it.
# Traceback (most recent call last):
#   File "/home/metaverse/miniconda3/envs/mutiah/lib/python3.9/site-packages/tensorboard/backend/application.py", line 123, in TensorBoardWSGIApp
#     plugin = loader.load(context)
#   File "/home/metaverse/miniconda3/envs/mutiah/lib/python3.9/site-packages/tensorboard_plugin_wit/wit_plugin_loader.py", line 57, in load
#     from tensorboard_plugin_wit.wit_plugin import WhatIfToolPlugin
#   File "/home/metaverse/miniconda3/envs/mutiah/lib/python3.9/site-packages/tensorboard_plugin_wit/wit_plugin.py", line 40, in <module>
#     from tensorboard_plugin_wit._utils import common_utils
#   File "/home/metaverse/miniconda3/envs/mutiah/lib/python3.9/site-packages/tensorboard_plugin_wit/_utils/common_utils.py", line 17, in <module>
#     from tensorboard_plugin_wit._vendor.tensorflow_serving.apis import classification_pb2
#   File "/home/metaverse/miniconda3/envs/mutiah/lib/python3.9/site-packages/tensorboard_plugin_wit/_vendor/tensorflow_serving/apis/classification_pb2.py", line 15, in <module>
#     from tensorboard_plugin_wit._vendor.tensorflow_serving.apis import input_pb2 as tensorflow__serving_dot_apis_dot_input__pb2
#   File "/home/metaverse/miniconda3/envs/mutiah/lib/python3.9/site-packages/tensorboard_plugin_wit/_vendor/tensorflow_serving/apis/input_pb2.py", line 37, in <module>
#     _descriptor.FieldDescriptor(
#   File "/home/metaverse/miniconda3/envs/mutiah/lib/python3.9/site-packages/google/protobuf/descriptor.py", line 561, in __new__
#     _message.Message._CheckCalledFromGeneratedFile()
# TypeError: Descriptors cannot not be created directly.
# If this call came from a _pb2.py file, your generated code is out of date and must be regenerated with protoc >= 3.19.0.
# If you cannot immediately regenerate your protos, some other possible workarounds are:
#  1. Downgrade the protobuf package to 3.20.x or lower.
#  2. Set PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION=python (but this will use pure-Python parsing and will be much slower).
#
# More information: https://developers.google.com/protocol-buffers/docs/news/2022-05-06#python-updates
# Address already in use
# Port 6006 is in use by another program. Either identify and stop that program, or start the server with a different port.
